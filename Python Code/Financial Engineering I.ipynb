# %%
import numpy as np

# np.pv(rate,nper,pmt,fv,when='begin' or 'end')

np.pv(0.1,20,-500000,0,'begin')/1000000
# Out:
# 4.68246004586721

# %%
u = 0.063
v = 0.069

f = ((1+v)**2/(1+u)**1)**(1/1)-1
f
# Out:
# 0.07503386641580434
